# %%
import pandas as pd

# %%
table = pd.read_csv("synthetic_stock_data.csv")

# %%
table
# Out:
#            Date        Company          Sector        Open        High  \
# 0    2022-01-01           Uber      Technology  100.000000  101.036120
# 1    2022-01-02          Tesla      Automotive  100.071106  102.037960
# 2    2022-01-03      Panasonic         Finance   99.857828  101.517497
# 3    2022-01-04        Tencent      Automotive   98.851663  101.303783
# 4    2022-01-05    Wells Fargo      Automotive   98.391118   99.990486
# ..          ...            ...             ...         ...         ...
# 995  2024-09-22         Pfizer          Energy  121.428608  123.693983
# 996  2024-09-23      Panasonic  Consumer Goods  122.302376  124.731488
# 997  2024-09-24  Goldman Sachs          Energy  120.638302  122.485538
# 998  2024-09-25           Lyft       Aerospace  120.228806  123.124765
# 999  2024-09-26         Boeing          Energy  120.558294  123.699478
#
#             Low       Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  \
# ...

# %% [markdown]
# ### Wybieranie danych
#
# SELECT col1, col2
# FROM table;

# %%
table[["Company", "Open"]]
# Out:
#            Company        Open
# 0             Uber  100.000000
# 1            Tesla  100.071106
# 2        Panasonic   99.857828
# 3          Tencent   98.851663
# 4      Wells Fargo   98.391118
# ..             ...         ...
# 995         Pfizer  121.428608
# 996      Panasonic  122.302376
# 997  Goldman Sachs  120.638302
# 998           Lyft  120.228806
# 999         Boeing  120.558294
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Filtrowanie wierszy
#
# SELECT *
# FROM table
# WHERE age > 30;

# %%
table[table["Open"] > 100]
# Out:
#            Date        Company          Sector        Open        High  \
# 1    2022-01-02          Tesla      Automotive  100.071106  102.037960
# 6    2022-01-07          Adobe      Technology  100.550082  102.752035
# 7    2022-01-08         Oracle      Technology  100.901312  103.512423
# 8    2022-01-09       Novartis       Aerospace  101.063050  104.073397
# 21   2022-01-22         Square         Finance  100.931276  103.536520
# ..          ...            ...             ...         ...         ...
# 995  2024-09-22         Pfizer          Energy  121.428608  123.693983
# 996  2024-09-23      Panasonic  Consumer Goods  122.302376  124.731488
# 997  2024-09-24  Goldman Sachs          Energy  120.638302  122.485538
# 998  2024-09-25           Lyft       Aerospace  120.228806  123.124765
# 999  2024-09-26         Boeing          Energy  120.558294  123.699478
#
#             Low       Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  \
# ...

# %% [markdown]
# ### Sortowanie
#
# SELECT *
# FROM table
# ORDER BY age DESC;

# %%
table.sort_values("Sector", ascending=False)
# Out:
#            Date     Company      Sector        Open        High         Low  \
# 0    2022-01-01        Uber  Technology  100.000000  101.036120   97.477809
# 584  2023-08-08       Shell  Technology  115.118679  116.415284  112.869217
# 639  2023-10-02      Toyota  Technology  117.846360  119.488982  115.115877
# 637  2023-09-30        Meta  Technology  120.105497  123.006959  118.523507
# 632  2023-09-25  MasterCard  Technology  120.234928  121.511283  118.213488
# ..          ...         ...         ...         ...         ...         ...
# 601  2023-08-25      Toyota   Aerospace  113.809592  116.638264  110.729453
# 149  2022-05-30     Tencent   Aerospace   96.228014   98.106425   94.177698
# 821  2024-04-01          BP   Aerospace  121.034722  122.743850  119.709793
# 220  2022-08-09      PayPal   Aerospace   88.275885   89.382357   86.563537
# 400  2023-02-05         IBM   Aerospace  109.866898  112.849110  107.240470
#
# ...

# %% [markdown]
# ### Agregacje
#
# SELECT col1, AVG(col2)
# FROM table
# GROUP BY col1;

# %%
table.groupby("Company")['Open'].mean()
# Out:
# Company
# AMD            109.493688
# Adobe          108.946566
# Airbus         111.300863
# Alibaba        109.463744
# Amazon         111.723653
#                   ...
# Toyota         111.718418
# Twitter        110.881408
# Uber           110.841806
# Visa           108.912266
# Wells Fargo    109.753846
# Name: Open, Length: 63, dtype: float64

# %% [markdown]
# ### Łączenie tabel
#
# SELECT *
# FROM table1
# JOIN table2
# ON table1.id = table2.id;

# %%
table1 = table.iloc[:,:2]
table2 = table.iloc[:,1:]

# %%
merged_table = pd.merge(table1, table2, left_on="Company", right_on="Company")
merged_table
# Out:
#              Date Company          Sector        Open        High         Low  \
# 0      2022-01-01    Uber      Technology  100.000000  101.036120   97.477809
# 1      2022-01-01    Uber      Technology   92.278528   94.948778   90.803581
# 2      2022-01-01    Uber  Consumer Goods   95.188667   97.451578   93.192414
# 3      2022-01-01    Uber          Energy   93.548490   96.221600   91.929231
# 4      2022-01-01    Uber       Aerospace   94.254003   95.388359   92.064753
# ...           ...     ...             ...         ...         ...         ...
# 16841  2024-09-26  Boeing       Aerospace  114.195556  116.613600  111.877551
# 16842  2024-09-26  Boeing         Finance  112.653205  115.039619  111.376564
# 16843  2024-09-26  Boeing       Aerospace  127.815367  131.168764  124.291407
# 16844  2024-09-26  Boeing         Finance  128.001566  131.335904  124.323044
# 16845  2024-09-26  Boeing          Energy  120.558294  123.699478  117.628380
#
# ...

# %% [markdown]
# ### Wartości NULL
#
# SELECT *
# FROM table
# WHERE col1 IS/IS NOT NULL;

# %%
table.iloc[0:3, 2] = pd.NA
table
# Out:
#            Date        Company          Sector        Open        High  \
# 0    2022-01-01           Uber            <NA>  100.000000  101.036120
# 1    2022-01-02          Tesla            <NA>  100.071106  102.037960
# 2    2022-01-03      Panasonic            <NA>   99.857828  101.517497
# 3    2022-01-04        Tencent      Automotive   98.851663  101.303783
# 4    2022-01-05    Wells Fargo      Automotive   98.391118   99.990486
# ..          ...            ...             ...         ...         ...
# 995  2024-09-22         Pfizer          Energy  121.428608  123.693983
# 996  2024-09-23      Panasonic  Consumer Goods  122.302376  124.731488
# 997  2024-09-24  Goldman Sachs          Energy  120.638302  122.485538
# 998  2024-09-25           Lyft       Aerospace  120.228806  123.124765
# 999  2024-09-26         Boeing          Energy  120.558294  123.699478
#
#             Low       Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  \
# ...

# %%
table[table['Sector'].isnull()]
# Out:
#          Date    Company Sector        Open        High        Low  \
# 0  2022-01-01       Uber   <NA>  100.000000  101.036120  97.477809
# 1  2022-01-02      Tesla   <NA>  100.071106  102.037960  97.152675
# 2  2022-01-03  Panasonic   <NA>   99.857828  101.517497  98.108097
#
#         Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  Volatility  \
# 0  100.000000  171958  5.156585e+11  24.253218        0.163090    0.047484
# 1  100.071106  196867  9.755658e+11  18.602848        0.288515    0.022472
# 2   99.857828  181932  4.595300e+11  10.728933        2.221827    0.019991
#
#    Sentiment_Score    Trend
# 0         0.939232  Bearish
# 1         0.469417  Bearish
# 2         0.399193  Bullish

# %% [markdown]
# ### Dodawanie kolumn
#
# ALTER TABLE table
# ADD COLUMN new_col INT;

# %%
table["new_col"] = table["High"] - table["Low"]
table
# Out:
#            Date        Company          Sector        Open        High  \
# 0    2022-01-01           Uber            <NA>  100.000000  101.036120
# 1    2022-01-02          Tesla            <NA>  100.071106  102.037960
# 2    2022-01-03      Panasonic            <NA>   99.857828  101.517497
# 3    2022-01-04        Tencent      Automotive   98.851663  101.303783
# 4    2022-01-05    Wells Fargo      Automotive   98.391118   99.990486
# ..          ...            ...             ...         ...         ...
# 995  2024-09-22         Pfizer          Energy  121.428608  123.693983
# 996  2024-09-23      Panasonic  Consumer Goods  122.302376  124.731488
# 997  2024-09-24  Goldman Sachs          Energy  120.638302  122.485538
# 998  2024-09-25           Lyft       Aerospace  120.228806  123.124765
# 999  2024-09-26         Boeing          Energy  120.558294  123.699478
#
#             Low       Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  \
# ...

# %% [markdown]
# ### Operacje matematyczne
#
# SELECT col1 + col2
# FROM table;

# %%
table["High"] - table["Low"]
# Out:
# 0      3.558311
# 1      4.885285
# 2      3.409401
# 3      4.305565
# 4      3.759780
#          ...
# 995    4.268488
# 996    4.549072
# 997    4.350505
# 998    5.165752
# 999    6.071098
# Length: 1000, dtype: float64

# %% [markdown]
# ### Limit wyników
#
# SELECT *
# FROM table
# LIMIT 5;

# %%
table.head(5)
# Out:
#          Date      Company      Sector        Open        High        Low  \
# 0  2022-01-01         Uber        <NA>  100.000000  101.036120  97.477809
# 1  2022-01-02        Tesla        <NA>  100.071106  102.037960  97.152675
# 2  2022-01-03    Panasonic        <NA>   99.857828  101.517497  98.108097
# 3  2022-01-04      Tencent  Automotive   98.851663  101.303783  96.998218
# 4  2022-01-05  Wells Fargo  Automotive   98.391118   99.990486  96.230707
#
#         Close  Volume    Market_Cap   PE_Ratio  Dividend_Yield  Volatility  \
# 0  100.000000  171958  5.156585e+11  24.253218        0.163090    0.047484
# 1  100.071106  196867  9.755658e+11  18.602848        0.288515    0.022472
# 2   99.857828  181932  4.595300e+11  10.728933        2.221827    0.019991
# 3   98.851663  153694  5.577481e+11  14.582696        1.377740    0.036166
# 4   98.391118  169879  8.607714e+11  37.491114        3.110198    0.034770
#
#    Sentiment_Score    Trend   new_col
# ...

# %% [markdown]
# ### Unikalne wartości
#
# SELECT DISTINCT col
# FROM table;

# %%
table["Company"].unique()
# Out:
# array(['Uber', 'Tesla', 'Panasonic', 'Tencent', 'Wells Fargo', 'Snapchat',
#        'Adobe', 'Oracle', 'Novartis', 'Microsoft', 'Citigroup', 'HSBC',
#        'Morgan Stanley', 'AstraZeneca', 'Moderna', 'Apple', 'Square',
#        'Ferrari', 'PayPal', 'BP', 'Salesforce', 'Shell', 'Lamborghini',
#        'Sony', 'Meta', 'Boeing', 'Lyft', 'IBM', 'Toyota', 'ExxonMobil',
#        'Goldman Sachs', 'Intel', 'Chevron', 'Bank of America', 'LG',
#        'AMD', 'Visa', 'Airbus', 'Mercedes-Benz', 'Nvidia', 'BMW',
#        'SpaceX', 'Pfizer', 'Spotify', 'Netflix', 'TotalEnergies',
#        'Samsung', 'Google', 'Roche', 'MasterCard', 'Ford',
#        'Northrop Grumman', 'Amazon', 'General Motors', 'Alibaba',
#        'Twitter', 'Lockheed Martin', 'Gilead Sciences', 'Porsche',
#        'Johnson & Johnson', 'JPMorgan Chase', 'Raytheon', 'Honda'],
#       dtype=object)
